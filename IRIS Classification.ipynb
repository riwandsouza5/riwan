# %%
import numpy as np

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
iris_data = load_iris() # load the iris dataset

x = iris_data.data
y_ = iris_data.target.reshape(-1, 1) # Convert data to a single column

# %%
# One Hot encode the class labels
encoder = OneHotEncoder(sparse=False)
y = encoder.fit_transform(y_)
# Out:
# C:\Users\GPTINF05\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
# Split the data for training and testing
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.20)

# %%
# Build the model
model = Sequential()
model.add(Dense(10, input_shape=(4,), activation='relu', name='input'))
model.add(Dense(10, activation='relu', name='fc2'))
model.add(Dense(3, activation='softmax', name='output'))

# %%
# Adam optimizer with learning rate of 0.001
optimizer = Adam(lr=0.001)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

print('Neural Network Model Summary: ')
print(model.summary())
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Neural Network Model Summary:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (Dense)               (None, 10)                50
#
#  fc2 (Dense)                 (None, 10)                110
#
#  output (Dense)              (None, 3)                 33
#
# =================================================================
# Total params: 193 (772.00 Byte)
# Trainable params: 193 (772.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# Train the model
model.fit(train_x, train_y, verbose=2, batch_size=5, epochs=200)
# Out:
# Epoch 1/200
# 24/24 - 1s - loss: 2.0625 - accuracy: 0.3417 - 1s/epoch - 52ms/step
# Epoch 2/200
# 24/24 - 0s - loss: 1.5574 - accuracy: 0.3417 - 46ms/epoch - 2ms/step
# Epoch 3/200
# 24/24 - 0s - loss: 1.3122 - accuracy: 0.3417 - 131ms/epoch - 5ms/step
# Epoch 4/200
# 24/24 - 0s - loss: 1.1894 - accuracy: 0.6250 - 31ms/epoch - 1ms/step
# Epoch 5/200
# 24/24 - 0s - loss: 1.1164 - accuracy: 0.6500 - 56ms/epoch - 2ms/step
# Epoch 6/200
# 24/24 - 0s - loss: 1.0732 - accuracy: 0.6167 - 29ms/epoch - 1ms/step
# Epoch 7/200
# 24/24 - 0s - loss: 1.0360 - accuracy: 0.6500 - 48ms/epoch - 2ms/step
# Epoch 8/200
# 24/24 - 0s - loss: 1.0062 - accuracy: 0.6250 - 34ms/epoch - 1ms/step
# Epoch 9/200
# 24/24 - 0s - loss: 0.9752 - accuracy: 0.6333 - 50ms/epoch - 2ms/step
# Epoch 10/200
# 24/24 - 0s - loss: 0.9437 - accuracy: 0.6500 - 57ms/epoch - 2ms/step
# Epoch 11/200
# 24/24 - 0s - loss: 0.9117 - accuracy: 0.6583 - 47ms/epoch - 2ms/step
# Epoch 12/200
# 24/24 - 0s - loss: 0.8761 - accuracy: 0.6583 - 39ms/epoch - 2ms/step
# Epoch 13/200
# 24/24 - 0s - loss: 0.8401 - accuracy: 0.6833 - 40ms/epoch - 2ms/step
# Epoch 14/200
# 24/24 - 0s - loss: 0.8029 - accuracy: 0.6667 - 21ms/epoch - 888us/step
# Epoch 15/200
# 24/24 - 0s - loss: 0.7726 - accuracy: 0.6583 - 32ms/epoch - 1ms/step
# Epoch 16/200
# 24/24 - 0s - loss: 0.7310 - accuracy: 0.6583 - 31ms/epoch - 1ms/step
# Epoch 17/200
# 24/24 - 0s - loss: 0.6954 - accuracy: 0.6583 - 31ms/epoch - 1ms/step
# Epoch 18/200
# 24/24 - 0s - loss: 0.6650 - accuracy: 0.7667 - 47ms/epoch - 2ms/step
# Epoch 19/200
# 24/24 - 0s - loss: 0.6342 - accuracy: 0.6750 - 31ms/epoch - 1ms/step
# Epoch 20/200
# 24/24 - 0s - loss: 0.5972 - accuracy: 0.7667 - 31ms/epoch - 1ms/step
# Epoch 21/200
# 24/24 - 0s - loss: 0.5620 - accuracy: 0.7667 - 31ms/epoch - 1ms/step
# Epoch 22/200
# 24/24 - 0s - loss: 0.5376 - accuracy: 0.8667 - 31ms/epoch - 1ms/step
# Epoch 23/200
# 24/24 - 0s - loss: 0.5248 - accuracy: 0.7250 - 31ms/epoch - 1ms/step
# Epoch 24/200
# 24/24 - 0s - loss: 0.4994 - accuracy: 0.8667 - 31ms/epoch - 1ms/step
# Epoch 25/200
# 24/24 - 0s - loss: 0.4809 - accuracy: 0.9000 - 31ms/epoch - 1ms/step
# Epoch 26/200
# 24/24 - 0s - loss: 0.4609 - accuracy: 0.8083 - 60ms/epoch - 2ms/step
# Epoch 27/200
# 24/24 - 0s - loss: 0.4385 - accuracy: 0.9417 - 62ms/epoch - 3ms/step
# Epoch 28/200
# 24/24 - 0s - loss: 0.4214 - accuracy: 0.9083 - 38ms/epoch - 2ms/step
# Epoch 29/200
# 24/24 - 0s - loss: 0.4053 - accuracy: 0.9417 - 36ms/epoch - 2ms/step
# Epoch 30/200
# 24/24 - 0s - loss: 0.3916 - accuracy: 0.9417 - 68ms/epoch - 3ms/step
# Epoch 31/200
# 24/24 - 0s - loss: 0.3844 - accuracy: 0.9417 - 40ms/epoch - 2ms/step
# Epoch 32/200
# 24/24 - 0s - loss: 0.3631 - accuracy: 0.9167 - 35ms/epoch - 1ms/step
# Epoch 33/200
# 24/24 - 0s - loss: 0.3540 - accuracy: 0.9333 - 36ms/epoch - 2ms/step
# Epoch 34/200
# 24/24 - 0s - loss: 0.3358 - accuracy: 0.9583 - 39ms/epoch - 2ms/step
# Epoch 35/200
# 24/24 - 0s - loss: 0.3232 - accuracy: 0.9417 - 67ms/epoch - 3ms/step
# Epoch 36/200
# 24/24 - 0s - loss: 0.3177 - accuracy: 0.9500 - 51ms/epoch - 2ms/step
# Epoch 37/200
# 24/24 - 0s - loss: 0.3012 - accuracy: 0.9583 - 50ms/epoch - 2ms/step
# Epoch 38/200
# 24/24 - 0s - loss: 0.2910 - accuracy: 0.9667 - 50ms/epoch - 2ms/step
# Epoch 39/200
# 24/24 - 0s - loss: 0.2818 - accuracy: 0.9500 - 64ms/epoch - 3ms/step
# Epoch 40/200
# 24/24 - 0s - loss: 0.2721 - accuracy: 0.9583 - 49ms/epoch - 2ms/step
# Epoch 41/200
# 24/24 - 0s - loss: 0.2657 - accuracy: 0.9583 - 45ms/epoch - 2ms/step
# Epoch 42/200
# 24/24 - 0s - loss: 0.2632 - accuracy: 0.9583 - 33ms/epoch - 1ms/step
# Epoch 43/200
# 24/24 - 0s - loss: 0.2490 - accuracy: 0.9333 - 31ms/epoch - 1ms/step
# Epoch 44/200
# 24/24 - 0s - loss: 0.2516 - accuracy: 0.9250 - 31ms/epoch - 1ms/step
# Epoch 45/200
# 24/24 - 0s - loss: 0.2387 - accuracy: 0.9250 - 31ms/epoch - 1ms/step
# Epoch 46/200
# 24/24 - 0s - loss: 0.2320 - accuracy: 0.9667 - 31ms/epoch - 1ms/step
# Epoch 47/200
# 24/24 - 0s - loss: 0.2300 - accuracy: 0.9500 - 40ms/epoch - 2ms/step
# Epoch 48/200
# 24/24 - 0s - loss: 0.2127 - accuracy: 0.9667 - 35ms/epoch - 1ms/step
# Epoch 49/200
# 24/24 - 0s - loss: 0.2094 - accuracy: 0.9667 - 38ms/epoch - 2ms/step
# Epoch 50/200
# 24/24 - 0s - loss: 0.2033 - accuracy: 0.9750 - 39ms/epoch - 2ms/step
# Epoch 51/200
# 24/24 - 0s - loss: 0.1956 - accuracy: 0.9750 - 40ms/epoch - 2ms/step
# Epoch 52/200
# 24/24 - 0s - loss: 0.1944 - accuracy: 0.9583 - 40ms/epoch - 2ms/step
# Epoch 53/200
# 24/24 - 0s - loss: 0.1853 - accuracy: 0.9750 - 41ms/epoch - 2ms/step
# Epoch 54/200
# 24/24 - 0s - loss: 0.1810 - accuracy: 0.9750 - 39ms/epoch - 2ms/step
# Epoch 55/200
# 24/24 - 0s - loss: 0.1768 - accuracy: 0.9750 - 39ms/epoch - 2ms/step
# Epoch 56/200
# 24/24 - 0s - loss: 0.1799 - accuracy: 0.9583 - 37ms/epoch - 2ms/step
# Epoch 57/200
# 24/24 - 0s - loss: 0.1693 - accuracy: 0.9750 - 37ms/epoch - 2ms/step
# Epoch 58/200
# 24/24 - 0s - loss: 0.1768 - accuracy: 0.9417 - 31ms/epoch - 1ms/step
# Epoch 59/200
# 24/24 - 0s - loss: 0.1769 - accuracy: 0.9667 - 31ms/epoch - 1ms/step
# Epoch 60/200
# 24/24 - 0s - loss: 0.1667 - accuracy: 0.9750 - 31ms/epoch - 1ms/step
# Epoch 61/200
# 24/24 - 0s - loss: 0.1579 - accuracy: 0.9500 - 43ms/epoch - 2ms/step
# Epoch 62/200
# 24/24 - 0s - loss: 0.1565 - accuracy: 0.9750 - 40ms/epoch - 2ms/step
# Epoch 63/200
# 24/24 - 0s - loss: 0.1555 - accuracy: 0.9667 - 39ms/epoch - 2ms/step
# Epoch 64/200
# 24/24 - 0s - loss: 0.1485 - accuracy: 0.9750 - 36ms/epoch - 2ms/step
# Epoch 65/200
# 24/24 - 0s - loss: 0.1467 - accuracy: 0.9500 - 22ms/epoch - 937us/step
# Epoch 66/200
# 24/24 - 0s - loss: 0.1495 - accuracy: 0.9750 - 47ms/epoch - 2ms/step
# Epoch 67/200
# 24/24 - 0s - loss: 0.1403 - accuracy: 0.9667 - 33ms/epoch - 1ms/step
# Epoch 68/200
# 24/24 - 0s - loss: 0.1406 - accuracy: 0.9667 - 31ms/epoch - 1ms/step
# Epoch 69/200
# 24/24 - 0s - loss: 0.1409 - accuracy: 0.9750 - 39ms/epoch - 2ms/step
# Epoch 70/200
# 24/24 - 0s - loss: 0.1357 - accuracy: 0.9583 - 38ms/epoch - 2ms/step
# Epoch 71/200
# 24/24 - 0s - loss: 0.1317 - accuracy: 0.9750 - 36ms/epoch - 1ms/step
# Epoch 72/200
# 24/24 - 0s - loss: 0.1331 - accuracy: 0.9750 - 19ms/epoch - 779us/step
# Epoch 73/200
# 24/24 - 0s - loss: 0.1304 - accuracy: 0.9667 - 31ms/epoch - 1ms/step
# Epoch 74/200
# 24/24 - 0s - loss: 0.1292 - accuracy: 0.9750 - 31ms/epoch - 1ms/step
# Epoch 75/200
# 24/24 - 0s - loss: 0.1270 - accuracy: 0.9667 - 31ms/epoch - 1ms/step
# Epoch 76/200
# 24/24 - 0s - loss: 0.1300 - accuracy: 0.9667 - 31ms/epoch - 1ms/step
# Epoch 77/200
# 24/24 - 0s - loss: 0.1233 - accuracy: 0.9750 - 31ms/epoch - 1ms/step
# Epoch 78/200
# 24/24 - 0s - loss: 0.1226 - accuracy: 0.9667 - 31ms/epoch - 1ms/step
# Epoch 79/200
# 24/24 - 0s - loss: 0.1214 - accuracy: 0.9750 - 31ms/epoch - 1ms/step
# Epoch 80/200
# 24/24 - 0s - loss: 0.1182 - accuracy: 0.9667 - 31ms/epoch - 1ms/step
# Epoch 81/200
# 24/24 - 0s - loss: 0.1179 - accuracy: 0.9750 - 37ms/epoch - 2ms/step
# Epoch 82/200
# 24/24 - 0s - loss: 0.1158 - accuracy: 0.9583 - 31ms/epoch - 1ms/step
# Epoch 83/200
# 24/24 - 0s - loss: 0.1199 - accuracy: 0.9750 - 31ms/epoch - 1ms/step
# Epoch 84/200
# 24/24 - 0s - loss: 0.1511 - accuracy: 0.9417 - 31ms/epoch - 1ms/step
# Epoch 85/200
# 24/24 - 0s - loss: 0.1170 - accuracy: 0.9500 - 37ms/epoch - 2ms/step
# Epoch 86/200
# 24/24 - 0s - loss: 0.1103 - accuracy: 0.9667 - 18ms/epoch - 768us/step
# Epoch 87/200
# 24/24 - 0s - loss: 0.1177 - accuracy: 0.9667 - 35ms/epoch - 1ms/step
# Epoch 88/200
# 24/24 - 0s - loss: 0.1165 - accuracy: 0.9583 - 31ms/epoch - 1ms/step
# Epoch 89/200
# 24/24 - 0s - loss: 0.1091 - accuracy: 0.9667 - 36ms/epoch - 1ms/step
# Epoch 90/200
# 24/24 - 0s - loss: 0.1049 - accuracy: 0.9750 - 42ms/epoch - 2ms/step
# Epoch 91/200
# 24/24 - 0s - loss: 0.1084 - accuracy: 0.9583 - 23ms/epoch - 949us/step
# Epoch 92/200
# 24/24 - 0s - loss: 0.1165 - accuracy: 0.9750 - 31ms/epoch - 1ms/step
# Epoch 93/200
# 24/24 - 0s - loss: 0.1115 - accuracy: 0.9500 - 31ms/epoch - 1ms/step
# Epoch 94/200
# 24/24 - 0s - loss: 0.1073 - accuracy: 0.9750 - 31ms/epoch - 1ms/step
# Epoch 95/200
# 24/24 - 0s - loss: 0.1021 - accuracy: 0.9667 - 31ms/epoch - 1ms/step
# Epoch 96/200
# 24/24 - 0s - loss: 0.1029 - accuracy: 0.9667 - 27ms/epoch - 1ms/step
# Epoch 97/200
# 24/24 - 0s - loss: 0.1056 - accuracy: 0.9667 - 31ms/epoch - 1ms/step
# Epoch 98/200
# 24/24 - 0s - loss: 0.1030 - accuracy: 0.9583 - 73ms/epoch - 3ms/step
# Epoch 99/200
# 24/24 - 0s - loss: 0.0981 - accuracy: 0.9667 - 38ms/epoch - 2ms/step
# Epoch 100/200
# 24/24 - 0s - loss: 0.0993 - accuracy: 0.9750 - 57ms/epoch - 2ms/step
# Epoch 101/200
# 24/24 - 0s - loss: 0.1074 - accuracy: 0.9667 - 39ms/epoch - 2ms/step
# Epoch 102/200
# 24/24 - 0s - loss: 0.1038 - accuracy: 0.9667 - 38ms/epoch - 2ms/step
# Epoch 103/200
# 24/24 - 0s - loss: 0.1006 - accuracy: 0.9583 - 37ms/epoch - 2ms/step
# Epoch 104/200
# 24/24 - 0s - loss: 0.1048 - accuracy: 0.9750 - 37ms/epoch - 2ms/step
# Epoch 105/200
# 24/24 - 0s - loss: 0.0948 - accuracy: 0.9667 - 37ms/epoch - 2ms/step
# Epoch 106/200
# 24/24 - 0s - loss: 0.1006 - accuracy: 0.9750 - 38ms/epoch - 2ms/step
# Epoch 107/200
# 24/24 - 0s - loss: 0.0982 - accuracy: 0.9500 - 39ms/epoch - 2ms/step
# Epoch 108/200
# 24/24 - 0s - loss: 0.1059 - accuracy: 0.9583 - 37ms/epoch - 2ms/step
# Epoch 109/200
# 24/24 - 0s - loss: 0.0930 - accuracy: 0.9750 - 36ms/epoch - 1ms/step
# Epoch 110/200
# 24/24 - 0s - loss: 0.0933 - accuracy: 0.9667 - 35ms/epoch - 1ms/step
# Epoch 111/200
# 24/24 - 0s - loss: 0.1010 - accuracy: 0.9583 - 32ms/epoch - 1ms/step
# Epoch 112/200
# 24/24 - 0s - loss: 0.0946 - accuracy: 0.9750 - 31ms/epoch - 1ms/step
# Epoch 113/200
# 24/24 - 0s - loss: 0.0908 - accuracy: 0.9667 - 31ms/epoch - 1ms/step
# Epoch 114/200
# 24/24 - 0s - loss: 0.0911 - accuracy: 0.9667 - 31ms/epoch - 1ms/step
# Epoch 115/200
# 24/24 - 0s - loss: 0.0898 - accuracy: 0.9750 - 41ms/epoch - 2ms/step
# Epoch 116/200
# 24/24 - 0s - loss: 0.1011 - accuracy: 0.9583 - 40ms/epoch - 2ms/step
# Epoch 117/200
# 24/24 - 0s - loss: 0.0942 - accuracy: 0.9667 - 23ms/epoch - 968us/step
# Epoch 118/200
# 24/24 - 0s - loss: 0.0941 - accuracy: 0.9750 - 31ms/epoch - 1ms/step
# Epoch 119/200
# 24/24 - 0s - loss: 0.0892 - accuracy: 0.9750 - 31ms/epoch - 1ms/step
# Epoch 120/200
# 24/24 - 0s - loss: 0.0883 - accuracy: 0.9583 - 31ms/epoch - 1ms/step
# Epoch 121/200
# 24/24 - 0s - loss: 0.0884 - accuracy: 0.9667 - 31ms/epoch - 1ms/step
# Epoch 122/200
# 24/24 - 0s - loss: 0.0886 - accuracy: 0.9667 - 39ms/epoch - 2ms/step
# Epoch 123/200
# 24/24 - 0s - loss: 0.0879 - accuracy: 0.9667 - 37ms/epoch - 2ms/step
# Epoch 124/200
# 24/24 - 0s - loss: 0.0892 - accuracy: 0.9750 - 36ms/epoch - 2ms/step
# Epoch 125/200
# 24/24 - 0s - loss: 0.0968 - accuracy: 0.9750 - 37ms/epoch - 2ms/step
# Epoch 126/200
# 24/24 - 0s - loss: 0.0929 - accuracy: 0.9583 - 38ms/epoch - 2ms/step
# Epoch 127/200
# 24/24 - 0s - loss: 0.0961 - accuracy: 0.9583 - 40ms/epoch - 2ms/step
# Epoch 128/200
# 24/24 - 0s - loss: 0.0885 - accuracy: 0.9750 - 40ms/epoch - 2ms/step
# Epoch 129/200
# 24/24 - 0s - loss: 0.0864 - accuracy: 0.9500 - 39ms/epoch - 2ms/step
# Epoch 130/200
# 24/24 - 0s - loss: 0.0895 - accuracy: 0.9750 - 37ms/epoch - 2ms/step
# Epoch 131/200
# 24/24 - 0s - loss: 0.0957 - accuracy: 0.9500 - 39ms/epoch - 2ms/step
# Epoch 132/200
# 24/24 - 0s - loss: 0.0907 - accuracy: 0.9667 - 37ms/epoch - 2ms/step
# Epoch 133/200
# 24/24 - 0s - loss: 0.0889 - accuracy: 0.9583 - 58ms/epoch - 2ms/step
# Epoch 134/200
# 24/24 - 0s - loss: 0.0861 - accuracy: 0.9667 - 40ms/epoch - 2ms/step
# Epoch 135/200
# 24/24 - 0s - loss: 0.0858 - accuracy: 0.9583 - 38ms/epoch - 2ms/step
# Epoch 136/200
# 24/24 - 0s - loss: 0.0874 - accuracy: 0.9667 - 37ms/epoch - 2ms/step
# Epoch 137/200
# 24/24 - 0s - loss: 0.0831 - accuracy: 0.9667 - 44ms/epoch - 2ms/step
# Epoch 138/200
# 24/24 - 0s - loss: 0.0814 - accuracy: 0.9667 - 42ms/epoch - 2ms/step
# Epoch 139/200
# 24/24 - 0s - loss: 0.0815 - accuracy: 0.9667 - 33ms/epoch - 1ms/step
# Epoch 140/200
# 24/24 - 0s - loss: 0.0815 - accuracy: 0.9750 - 51ms/epoch - 2ms/step
# Epoch 141/200
# 24/24 - 0s - loss: 0.0820 - accuracy: 0.9667 - 50ms/epoch - 2ms/step
# Epoch 142/200
# 24/24 - 0s - loss: 0.0847 - accuracy: 0.9667 - 51ms/epoch - 2ms/step
# Epoch 143/200
# 24/24 - 0s - loss: 0.0815 - accuracy: 0.9750 - 49ms/epoch - 2ms/step
# Epoch 144/200
# 24/24 - 0s - loss: 0.0814 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 145/200
# 24/24 - 0s - loss: 0.0809 - accuracy: 0.9750 - 50ms/epoch - 2ms/step
# Epoch 146/200
# 24/24 - 0s - loss: 0.0814 - accuracy: 0.9667 - 38ms/epoch - 2ms/step
# Epoch 147/200
# 24/24 - 0s - loss: 0.0816 - accuracy: 0.9667 - 39ms/epoch - 2ms/step
# Epoch 148/200
# 24/24 - 0s - loss: 0.0811 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 149/200
# 24/24 - 0s - loss: 0.0786 - accuracy: 0.9750 - 47ms/epoch - 2ms/step
# Epoch 150/200
# 24/24 - 0s - loss: 0.0801 - accuracy: 0.9750 - 31ms/epoch - 1ms/step
# Epoch 151/200
# 24/24 - 0s - loss: 0.0894 - accuracy: 0.9500 - 31ms/epoch - 1ms/step
# Epoch 152/200
# 24/24 - 0s - loss: 0.0904 - accuracy: 0.9667 - 108ms/epoch - 4ms/step
# Epoch 153/200
# 24/24 - 0s - loss: 0.0859 - accuracy: 0.9667 - 55ms/epoch - 2ms/step
# Epoch 154/200
# 24/24 - 0s - loss: 0.0809 - accuracy: 0.9667 - 39ms/epoch - 2ms/step
# Epoch 155/200
# 24/24 - 0s - loss: 0.0776 - accuracy: 0.9667 - 46ms/epoch - 2ms/step
# Epoch 156/200
# 24/24 - 0s - loss: 0.0820 - accuracy: 0.9667 - 57ms/epoch - 2ms/step
# Epoch 157/200
# 24/24 - 0s - loss: 0.0844 - accuracy: 0.9500 - 50ms/epoch - 2ms/step
# Epoch 158/200
# 24/24 - 0s - loss: 0.0771 - accuracy: 0.9750 - 50ms/epoch - 2ms/step
# Epoch 159/200
# 24/24 - 0s - loss: 0.0755 - accuracy: 0.9667 - 51ms/epoch - 2ms/step
# Epoch 160/200
# 24/24 - 0s - loss: 0.0790 - accuracy: 0.9667 - 44ms/epoch - 2ms/step
# Epoch 161/200
# 24/24 - 0s - loss: 0.0773 - accuracy: 0.9750 - 38ms/epoch - 2ms/step
# Epoch 162/200
# 24/24 - 0s - loss: 0.0791 - accuracy: 0.9667 - 39ms/epoch - 2ms/step
# Epoch 163/200
# 24/24 - 0s - loss: 0.0820 - accuracy: 0.9750 - 39ms/epoch - 2ms/step
# Epoch 164/200
# 24/24 - 0s - loss: 0.0765 - accuracy: 0.9667 - 55ms/epoch - 2ms/step
# Epoch 165/200
# 24/24 - 0s - loss: 0.0759 - accuracy: 0.9667 - 65ms/epoch - 3ms/step
# Epoch 166/200
# 24/24 - 0s - loss: 0.0803 - accuracy: 0.9583 - 49ms/epoch - 2ms/step
# Epoch 167/200
# 24/24 - 0s - loss: 0.0799 - accuracy: 0.9750 - 49ms/epoch - 2ms/step
# Epoch 168/200
# 24/24 - 0s - loss: 0.0768 - accuracy: 0.9667 - 67ms/epoch - 3ms/step
# Epoch 169/200
# 24/24 - 0s - loss: 0.0738 - accuracy: 0.9667 - 48ms/epoch - 2ms/step
# Epoch 170/200
# 24/24 - 0s - loss: 0.0739 - accuracy: 0.9667 - 43ms/epoch - 2ms/step
# Epoch 171/200
# 24/24 - 0s - loss: 0.0747 - accuracy: 0.9667 - 39ms/epoch - 2ms/step
# Epoch 172/200
# 24/24 - 0s - loss: 0.0789 - accuracy: 0.9750 - 42ms/epoch - 2ms/step
# Epoch 173/200
# 24/24 - 0s - loss: 0.0750 - accuracy: 0.9667 - 44ms/epoch - 2ms/step
# Epoch 174/200
# 24/24 - 0s - loss: 0.0760 - accuracy: 0.9667 - 48ms/epoch - 2ms/step
# Epoch 175/200
# 24/24 - 0s - loss: 0.0731 - accuracy: 0.9667 - 50ms/epoch - 2ms/step
# Epoch 176/200
# 24/24 - 0s - loss: 0.0718 - accuracy: 0.9667 - 79ms/epoch - 3ms/step
# Epoch 177/200
# 24/24 - 0s - loss: 0.0746 - accuracy: 0.9750 - 43ms/epoch - 2ms/step
# Epoch 178/200
# 24/24 - 0s - loss: 0.0851 - accuracy: 0.9667 - 43ms/epoch - 2ms/step
# Epoch 179/200
# 24/24 - 0s - loss: 0.0790 - accuracy: 0.9750 - 41ms/epoch - 2ms/step
# Epoch 180/200
# 24/24 - 0s - loss: 0.0744 - accuracy: 0.9750 - 39ms/epoch - 2ms/step
# Epoch 181/200
# 24/24 - 0s - loss: 0.0756 - accuracy: 0.9667 - 38ms/epoch - 2ms/step
# Epoch 182/200
# 24/24 - 0s - loss: 0.0769 - accuracy: 0.9750 - 41ms/epoch - 2ms/step
# Epoch 183/200
# 24/24 - 0s - loss: 0.0756 - accuracy: 0.9750 - 39ms/epoch - 2ms/step
# Epoch 184/200
# 24/24 - 0s - loss: 0.0716 - accuracy: 0.9667 - 51ms/epoch - 2ms/step
# Epoch 185/200
# 24/24 - 0s - loss: 0.0732 - accuracy: 0.9667 - 48ms/epoch - 2ms/step
# Epoch 186/200
# 24/24 - 0s - loss: 0.0714 - accuracy: 0.9667 - 48ms/epoch - 2ms/step
# Epoch 187/200
# 24/24 - 0s - loss: 0.0691 - accuracy: 0.9667 - 50ms/epoch - 2ms/step
# Epoch 188/200
# 24/24 - 0s - loss: 0.0704 - accuracy: 0.9667 - 45ms/epoch - 2ms/step
# Epoch 189/200
# 24/24 - 0s - loss: 0.0758 - accuracy: 0.9583 - 48ms/epoch - 2ms/step
# Epoch 190/200
# 24/24 - 0s - loss: 0.0763 - accuracy: 0.9750 - 46ms/epoch - 2ms/step
# Epoch 191/200
# 24/24 - 0s - loss: 0.0710 - accuracy: 0.9750 - 56ms/epoch - 2ms/step
# Epoch 192/200
# 24/24 - 0s - loss: 0.0731 - accuracy: 0.9667 - 44ms/epoch - 2ms/step
# Epoch 193/200
# 24/24 - 0s - loss: 0.0893 - accuracy: 0.9417 - 46ms/epoch - 2ms/step
# Epoch 194/200
# 24/24 - 0s - loss: 0.0823 - accuracy: 0.9667 - 52ms/epoch - 2ms/step
# Epoch 195/200
# 24/24 - 0s - loss: 0.0749 - accuracy: 0.9667 - 44ms/epoch - 2ms/step
# Epoch 196/200
# 24/24 - 0s - loss: 0.0704 - accuracy: 0.9667 - 59ms/epoch - 2ms/step
# Epoch 197/200
# 24/24 - 0s - loss: 0.0805 - accuracy: 0.9667 - 42ms/epoch - 2ms/step
# Epoch 198/200
# 24/24 - 0s - loss: 0.0710 - accuracy: 0.9583 - 39ms/epoch - 2ms/step
# Epoch 199/200
# 24/24 - 0s - loss: 0.0763 - accuracy: 0.9750 - 39ms/epoch - 2ms/step
# Epoch 200/200
# 24/24 - 0s - loss: 0.0777 - accuracy: 0.9750 - 65ms/epoch - 3ms/step

# %%
results = model.evaluate(test_x, test_y)
print('Final test set accuracy:',results[1])
# Out:
# 1/1 [==============================] - 0s 219ms/step - loss: 0.0412 - accuracy: 0.9667
# Final test set accuracy: 0.9666666388511658

# %%
x_test1 = [[4.6, 3.4, 1.4, 0.3]] # for new data testing
y_pred1 = model.predict(x_test1)
print("Predicted class is:",y_pred1)
# Out:
# 1/1 [==============================] - 0s 108ms/step
# Predicted class is: [[9.9965131e-01 3.4257487e-04 6.0756383e-06]]

# %%
y_classes = y_pred1.argmax(axis=-1)
print("The above data belongs to class ",y_classes[0])
# Out:
# The above data belongs to class  0
